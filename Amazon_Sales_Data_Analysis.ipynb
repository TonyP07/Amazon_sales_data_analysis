# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_amazon = pd.read_csv("SALESDATA1.csv", encoding = "latin-1")
df_amazon.head()
# Out:
#       CustKey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000481.0  30-04-2017          -237.91   2017-04-30        100012.0
# 1  10002220.0  14-07-2017           368.79   2017-07-14        100233.0
# 2  10002220.0  17-10-2017           109.73   2017-10-17        116165.0
# 3  10002489.0  03-06-2017          -211.75   2017-06-03        100096.0
# 4  10004516.0  27-05-2017         96627.94   2017-05-27        103341.0
#
#   Item Class Item Number                             Item  Line Number  \
# 0        NaN         NaN                 Urban Large Eggs       2000.0
# 1        P01       20910               Moms Sliced Turkey       1000.0
# 2        P01       38076  Cutting Edge Foot-Long Hot Dogs       1000.0
# 3        NaN         NaN                         Kiwi Lox       1000.0
# 4        P01       60776             High Top Sweet Onion       1000.0
#
#    List Price  ...  Sales Cost Amount Sales Margin Amount  Sales Price  \
# ...

# %%
df_amazon_customers = pd.read_csv("CUSTOMERS.csv")
df_amazon_customers.head()
# Out:
#    Address Number Business Family  Business Unit              Customer  \
# 0        10000000              R3              1      City Supermarket
# 1        10000453              R3              1         A Supermarket
# 2        10000455              R3              1  Caribian Supermarket
# 3        10000456              R1              1              A&B Shop
# 4        10000457              O2              1              A&G Shop
#
#    Customer Number Customer Type  Division Line of Business         Phone  \
# 0         10000000            G2         2                   816-455-8733
# 1         10000453            G1         1                   816-455-8733
# 2         10000455            G2         2                   816-455-8733
# 3         10000456            G3         1                   816-455-8733
# 4         10000457            G1         1                   816-455-8733
#
#    Region Code Regional Sales Mgr Search Type
# 0            4                S16           C
# ...

# %%
df_customer_address = pd.read_csv("CUSTOMERADDRESS.csv")
df_customer_address.head()
# Out:
#    Address Number                       City Country  \
# 0        10000000                      Akron      US
# 1        10000453                                 UK
# 2        10000455           Huntington Beach      US
# 3        10000456                   Edmonton      CA
# 4        10000458                    Saginaw      US
#
#                          Customer Address 1  \
# 0                               PO Box 6258
# 1
# 2                         7392 Count Circle
# 3                          8151 Wagner Road
# 4                                PO Box 840
#
#                          Customer Address 2  \
# 0
# 1
# 2
# 3
# 4
#
#                          Customer Address 3  \
# 0
# 1
# 2
# 3
# 4
#
#                          Customer Address 4 State      Zip Code
# 0                                              OH         44312
# 1                                             NaN
# 2                                              CA         92647
# ...

# %%
df_region = pd.read_csv("REGION.csv")
df_region
# Out:
#    Region Code    Region Name
# 0            0         Canada
# 1            1        Western
# 2            2       Southern
# 3            3      Northeast
# 4            4        Central
# 5            5  International

# %%
df_amazon.head()
# Out:
#       CustKey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000481.0  30-04-2017          -237.91   2017-04-30        100012.0
# 1  10002220.0  14-07-2017           368.79   2017-07-14        100233.0
# 2  10002220.0  17-10-2017           109.73   2017-10-17        116165.0
# 3  10002489.0  03-06-2017          -211.75   2017-06-03        100096.0
# 4  10004516.0  27-05-2017         96627.94   2017-05-27        103341.0
#
#   Item Class Item Number                             Item  Line Number  \
# 0        NaN         NaN                 Urban Large Eggs       2000.0
# 1        P01       20910               Moms Sliced Turkey       1000.0
# 2        P01       38076  Cutting Edge Foot-Long Hot Dogs       1000.0
# 3        NaN         NaN                         Kiwi Lox       1000.0
# 4        P01       60776             High Top Sweet Onion       1000.0
#
#    List Price  ...  Sales Cost Amount Sales Margin Amount  Sales Price  \
# ...

# %%
df_amazon.shape
# Out:
# (65535, 24)

# %%
list(df_amazon.columns)
# Out:
# ['CustKey',
#  'DateKey',
#  'Discount Amount',
#  'Invoice Date',
#  'Invoice Number',
#  'Item Class',
#  'Item Number',
#  'Item',
#  'Line Number',
#  'List Price',
#  'Order Number',
#  'Promised Delivery Date',
#  'Sales Amount',
#  'Sales Amount Based on List Price',
#  'Sales Cost Amount',
#  'Sales Margin Amount',
#  'Sales Price',
#  'Sales Quantity',
#  'Sales Rep',
#  'Unit Of Measure',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23']

# %%
df_amazon["Unnamed: 20"].isnull().sum()
# Out:
# 65535

# %%
new_df_amazon = df_amazon.drop(columns = ["Unnamed: 20","Unnamed: 21","Unnamed: 22","Unnamed: 23"])

# %%
new_df_amazon.head()
# Out:
#       CustKey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000481.0  30-04-2017          -237.91   2017-04-30        100012.0
# 1  10002220.0  14-07-2017           368.79   2017-07-14        100233.0
# 2  10002220.0  17-10-2017           109.73   2017-10-17        116165.0
# 3  10002489.0  03-06-2017          -211.75   2017-06-03        100096.0
# 4  10004516.0  27-05-2017         96627.94   2017-05-27        103341.0
#
#   Item Class Item Number                             Item  Line Number  \
# 0        NaN         NaN                 Urban Large Eggs       2000.0
# 1        P01       20910               Moms Sliced Turkey       1000.0
# 2        P01       38076  Cutting Edge Foot-Long Hot Dogs       1000.0
# 3        NaN         NaN                         Kiwi Lox       1000.0
# 4        P01       60776             High Top Sweet Onion       1000.0
#
#    List Price  Order Number Promised Delivery Date  Sales Amount  \
# ...

# %%
new_df_amazon.shape
# Out:
# (65535, 20)

# %%
new_df_amazon.count()  # Counts number of non empty rows or columns as specified
# Out:
# CustKey                             65282
# DateKey                             65282
# Discount Amount                     65280
# Invoice Date                        65282
# Invoice Number                      65282
# Item Class                          56993
# Item Number                         65241
# Item                                65282
# Line Number                         65282
# List Price                          65282
# Order Number                        65282
# Promised Delivery Date              65282
# Sales Amount                        65282
# Sales Amount Based on List Price    65282
# Sales Cost Amount                   65282
# Sales Margin Amount                 65282
# Sales Price                         65281
# Sales Quantity                      65282
# Sales Rep                           65282
# Unit Of Measure                     65282
# dtype: int64

# %%
new_df_amazon.count(axis="columns").head(10)
# Out:
# 0    18
# 1    20
# 2    20
# 3    18
# 4    20
# 5    18
# 6    20
# 7    20
# 8    20
# 9    20
# dtype: int64

# %%
new_df_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CustKey                           65282 non-null  float64
#  1   DateKey                           65282 non-null  object
#  2   Discount Amount                   65280 non-null  float64
#  3   Invoice Date                      65282 non-null  object
#  4   Invoice Number                    65282 non-null  float64
#  5   Item Class                        56993 non-null  object
#  6   Item Number                       65241 non-null  object
#  7   Item                              65282 non-null  object
#  8   Line Number                       65282 non-null  float64
#  9   List Price                        65282 non-null  float64
#  10  Order Number                      65282 non-null  float64
# ...

# %%
new_df_amazon.describe()
# Out:
#             CustKey  Discount Amount  Invoice Number    Line Number  \
# count  6.528200e+04     65280.000000    65282.000000   65282.000000
# mean   1.001770e+07      1855.574835   216223.662020   23713.849790
# std    7.176148e+03      9037.140888    94992.281866   32664.024053
# min    1.000045e+07   -255820.800000   100012.000000    1000.000000
# 25%    1.001272e+07       246.037500   117931.000000    3000.000000
# 50%    1.001966e+07       441.760000   222869.500000   12000.000000
# 75%    1.002351e+07       999.760000   314318.750000   32000.000000
# max    1.002758e+07    343532.660000   332842.000000  344000.000000
#
#          List Price   Order Number   Sales Amount  \
# count  65282.000000   65282.000000   65282.000000
# mean     514.693380  180583.064352    2852.038373
# std      449.189182   67593.871116   15164.342107
# min        0.000000  100838.000000     200.010000
# 25%      181.560000  115321.000000     308.387500
# ...

# %%
new_df_amazon.describe(include = "O")
# Out:
#            DateKey Invoice Date Item Class Item Number  \
# count        65282        65282      56993       65241
# unique         559          559          2         983
# top     23-06-2017   2017-06-23        P01       17801
# freq           460          460      56977        1610
#
#                                 Item Promised Delivery Date Unit Of Measure
# count                          65282                  65282           65282
# unique                           657                    592               3
# top     Better Fancy Canned Sardines             27-06-2017              EA
# freq                            1648                    310           58994

# %%
new_df_amazon.head()
# Out:
#       CustKey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000481.0  30-04-2017          -237.91   2017-04-30        100012.0
# 1  10002220.0  14-07-2017           368.79   2017-07-14        100233.0
# 2  10002220.0  17-10-2017           109.73   2017-10-17        116165.0
# 3  10002489.0  03-06-2017          -211.75   2017-06-03        100096.0
# 4  10004516.0  27-05-2017         96627.94   2017-05-27        103341.0
#
#   Item Class Item Number                             Item  Line Number  \
# 0        NaN         NaN                 Urban Large Eggs       2000.0
# 1        P01       20910               Moms Sliced Turkey       1000.0
# 2        P01       38076  Cutting Edge Foot-Long Hot Dogs       1000.0
# 3        NaN         NaN                         Kiwi Lox       1000.0
# 4        P01       60776             High Top Sweet Onion       1000.0
#
#    List Price  Order Number Promised Delivery Date  Sales Amount  \
# ...

# %%
df_amazon_customers.head()
# Out:
#    Address Number Business Family  Business Unit              Customer  \
# 0        10000000              R3              1      City Supermarket
# 1        10000453              R3              1         A Supermarket
# 2        10000455              R3              1  Caribian Supermarket
# 3        10000456              R1              1              A&B Shop
# 4        10000457              O2              1              A&G Shop
#
#    Customer Number Customer Type  Division Line of Business         Phone  \
# 0         10000000            G2         2                   816-455-8733
# 1         10000453            G1         1                   816-455-8733
# 2         10000455            G2         2                   816-455-8733
# 3         10000456            G3         1                   816-455-8733
# 4         10000457            G1         1                   816-455-8733
#
#    Region Code Regional Sales Mgr Search Type
# 0            4                S16           C
# ...

# %%
df_customer_address.head()
# Out:
#    Address Number                       City Country  \
# 0        10000000                      Akron      US
# 1        10000453                                 UK
# 2        10000455           Huntington Beach      US
# 3        10000456                   Edmonton      CA
# 4        10000458                    Saginaw      US
#
#                          Customer Address 1  \
# 0                               PO Box 6258
# 1
# 2                         7392 Count Circle
# 3                          8151 Wagner Road
# 4                                PO Box 840
#
#                          Customer Address 2  \
# 0
# 1
# 2
# 3
# 4
#
#                          Customer Address 3  \
# 0
# 1
# 2
# 3
# 4
#
#                          Customer Address 4 State      Zip Code
# 0                                              OH         44312
# 1                                             NaN
# 2                                              CA         92647
# ...

# %%
df_region.head()
# Out:
#    Region Code Region Name
# 0            0      Canada
# 1            1     Western
# 2            2    Southern
# 3            3   Northeast
# 4            4     Central
